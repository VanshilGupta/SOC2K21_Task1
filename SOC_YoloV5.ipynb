# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 6990, done.
# remote: Counting objects: 100% (96/96), done.
# remote: Compressing objects: 100% (96/96), done.
# remote: Total 6990 (delta 48), reused 13 (delta 0), pack-reused 6894
# Receiving objects: 100% (6990/6990), 9.10 MiB | 33.53 MiB/s, done.
# Resolving deltas: 100% (4786/4786), done.

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
import torch
from IPython.display import Image, clear_output  # to display images
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.8.1+cu101 (Tesla T4)

# %%
# !python detect.py --source data/images/
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, half=False, hide_conf=False, hide_labels=False, img_size=640, iou_thres=0.45, line_thickness=3, max_det=1000, name='exp', nosave=False, project='runs/detect', save_conf=False, save_crop=False, save_txt=False, source='data/images/', update=False, view_img=False, weights='yolov5s.pt')
# requirements: PyYAML>=5.3.1 not found and is required by YOLOv5, attempting auto-update...
# ...
#   Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...
#
# requirements: 1 package updated per /content/yolov5/requirements.txt
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# YOLOv5 🚀 v5.0-160-gb6fdd2e torch 1.8.1+cu101 CUDA:0 (Tesla T4, 15109.75MB)
#
# ...
# 100% 14.1M/14.1M [00:00<00:00, 37.9MB/s]
#
# Fusing layers...
# Model Summary: 224 layers, 7266973 parameters, 0 gradients
# ...

# %%
Image(filename = "runs/detect/exp/zidane.jpg",width=600)

# %%
# !python detect.py --source 'https://www.youtube.com/watch?v=P54ruJHZvQI&ab_channel=AdamBelkoAdamBelko' --weights yolov5s.pt --conf 0.25
# Out:
# Streaming output truncated to the last 5000 lines.
# 0: 384x640 1 horse, Done. (0.008s)
# 0: 384x640 1 horse, Done. (0.007s)
# 0: 384x640 1 horse, Done. (0.008s)
# 0: 384x640 1 horse, Done. (0.009s)
# 0: 384x640 1 horse, Done. (0.008s)
# 0: 384x640 1 horse, Done. (0.008s)
# 0: 384x640 1 horse, Done. (0.007s)
# 0: 384x640 1 horse, Done. (0.007s)
# 0: 384x640 1 horse, Done. (0.009s)
# 0: 384x640 1 horse, Done. (0.007s)
# 0: 384x640 1 horse, Done. (0.007s)
# 0: 384x640 1 horse, Done. (0.007s)
# 0: 384x640 1 horse, Done. (0.007s)
# 0: 384x640 1 horse, Done. (0.009s)
# 0: 384x640 1 horse, Done. (0.007s)
# 0: 384x640 1 horse, Done. (0.007s)
# 0: 384x640 1 horse, Done. (0.008s)
# 0: 384x640 1 horse, Done. (0.007s)
# 0: 384x640 1 horse, Done. (0.007s)
# 0: 384x640 1 horse, Done. (0.007s)
# 0: 384x640 1 horse, Done. (0.007s)
# 0: 384x640 1 horse, Done. (0.008s)
# 0: 384x640 1 horse, Done. (0.007s)
# 0: 384x640 1 horse, Done. (0.007s)
# 0: 384x640 1 horse, Done. (0.008s)
# ...

# %%
Image(filename="runs/detect/exp/bus.jpg",width = 600)
